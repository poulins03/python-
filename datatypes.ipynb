# %%
salary=12000
taxrate=0.1
mytax=salary*taxrate
finalsalary=salary-mytax
print(finalsalary)
# Out:
# 10800.0

# %%
print("hello world")
a=5
b=7
print(a*b)
# Out:
# hello world
# 35

# %%
string_str="hello"
print(string_str.replace("h","a"))
mylist=[10,20,30,40,50]
print(mylist[2])
print(mylist[-1])
# Out:
# aello
# 30
# 50

# %%
a="sangeetha"
b=30
# print('my name is',(a),'age is',(b))

print(f'my name is {a} and age is {b}')
# Out:
# my name is sangeetha and age is 30

# %%
location=""

if location == 'bank':
    print('i can withdraw money')
elif location == 'autoshop':
    print('i can buy car')
else:
    print('i dont know much')
# Out:
# i can buy car

# %%
name="sangee"
if name =='anitha':
    print('hai anitha')
elif name == 'sumi':
    print('hai sumi')
else:
    print('hai')
# Out:
# hai
