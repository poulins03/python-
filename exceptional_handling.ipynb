# %%
def add(n1,n2):
    return n1+n2

# %%
num1=10
num2=0
try:
    def divd(num1,num2):
        return num1/num2
    
except ZeroDivisionError :
    print("you have a zero denominator,try different value")

except NameError:
    print("give a proper value")
else:
    print(divd(num1,num2))
finally:
    print("next lines of codes")
# Out:
# next lines of codes
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[13], line 15
#      11     print("give a proper value")
#      12 else:
#      13     print(divd(num1,num2))
#      14 finally:
# ---> 15     print("next lines of codes")
#      16
#
# Cell In[13], line 5, in divd(num1, num2)
#       4     def divd(num1,num2):
# ----> 5         return num1/num2
#
# ZeroDivisionError: division by zero
